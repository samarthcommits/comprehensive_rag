# %%
from database import CollectionDatabase
db_handler = CollectionDatabase()

# %%
db_handler.insert_collection(
                collection_name='remove',
                user_name='rem',
                retrieval_technique='retriever',
                database_type='database',
                chunking_strategy='chunking'
            )
# Out:
# True

# %%
from langchain_milvus import Milvus
from langchain_ollama import OllamaEmbeddings
from langchain_core.documents import Document
embeddings = OllamaEmbeddings(model="mxbai-embed-large:latest", base_url="http://10.10.64.25:11434")
collection_name = 'default1'
user_name = 'default'
URI = "http://127.0.0.1:19530"
client = Milvus.from_documents(
                documents=[Document(page_content="")],
                embedding=embeddings,
                collection_name=collection_name,
                connection_args={"uri": URI, 'db_name':user_name},
            )
# Out:
# ---------------------------------------------------------------------------
# ConnectTimeout                            Traceback (most recent call last)
# File c:\Users\samarth.srivastava\Desktop\new_check_proj\test_env2\lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\samarth.srivastava\Desktop\new_check_proj\test_env2\lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\samarth.srivastava\Desktop\new_check_proj\test_env2\lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
# ...

# %%
from pymilvus import MilvusClient
client = MilvusClient(uri="http://localhost:19530", timeout=30)

# %%
from database import CollectionDatabase

# %%
cd = CollectionDatabase()

# %%
c = cd.get_collection_info(user_name='default', collection_name='collect75')

# %%
print(c)
# Out:
# {'collection_id': 20, 'collection_name': 'collect75', 'user_name': 'default', 'retrieval_technique': 'Sparse Retrieval', 'database_type': 'MilvusDB', 'chunking_strategy': 'Recursive', 'created_at': '2025-10-26 18:15:11', 'updated_at': '2025-10-26 23:45:11.040674'}

# %%
from controller import Control

# %%
cont = Control()

# %%
ret = cont.create_retriever(user_name='default', collect_name='collect74', raw_text = '', database='MilvusDB')
# Out:
# collection_name =  collect77
# collect_name =  collect74
# collect_name1 =  collect74
# 00:08:08 httpx INFO   HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"

# %%
ret.get_relevant_documents('self attention')
# Out:
# C:\Users\samarth.srivastava\AppData\Local\Temp\ipykernel_27860\3499011868.py:1: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   ret.get_relevant_documents('self attention')
# 00:08:38 httpx INFO   HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# [Document(metadata={'pk': 461767297793573141}, page_content='')]

# %%
from database import UserDatabase

# %%
udb = UserDatabase()

# %%
udb.get_user_name_info(user_name='sammy')
# Out:
# {'user_id': 1,
#  'user_name': 'sammy',
#  'created_at': '2025-10-27 16:52:41',
#  'updated_at': '2025-10-27 22:22:41.816117'}

# %%
udb.validate_user(user_name='samy', password='samarth11')
# Out:
# False

# %%
l1 = [1, 2]
l2 = [2, 3]
list(set(l1+l2))
# Out:
# [1, 2, 3]

# %%
l1[[1, 2]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 l1[[1, 2]]
#
# TypeError: list indices must be integers or slices, not list

# %%
from database import CollectionDatabase, UserDatabase
cd = CollectionDatabase()
ud = UserDatabase()
cd.delete_all()
ud.delete_all()

# %%
from controller import Control

# %%
cont = Control()

# %%
ret = cont.create_retriever(database = 'MilvusDB', chunking = 'recursive', retriever = 'sparse', raw_text = '', collect_name = 'collect254', user_name = 'sam', pdf = None, chunks = None)
# Out:
# chunks - []
# collection_name =  collect267
# collect_name =  collect254
# collect_name1 =  collect254
# client created!
# [] -->metadatas????
# returning sparse retriever []

# %%
from pymilvus import connections, db, utility
from langchain_milvus import Milvus, BaseMilvusBuiltInFunction, BM25BuiltInFunction
from langchain_core.documents import Document
from langchain_ollama import OllamaEmbeddings

# %%
from pymilvus import connections, db, utility
from langchain_milvus import Milvus, BaseMilvusBuiltInFunction, BM25BuiltInFunction
from langchain_core.documents import Document
from langchain_ollama import OllamaEmbeddings
from uuid import uuid4
URI = "http://localhost:19530"
conn = connections.connect(host="127.0.0.1", port=19530)
user_name = 'sam'
collection_name = 'collect254'
database_list = db.list_database()
print(database_list)
client = None
if user_name not in database_list:
    db.create_database(db_name=user_name)
    print('hi')
conn = connections.connect(host="127.0.0.1", port=19530, db_name=user_name)
print(utility.list_collections())

if utility.has_collection(collection_name=collection_name):
    print('hi')
    client = Milvus(
            collection_name = collection_name,
            embedding_function = None,
            builtin_function=BM25BuiltInFunction(
                                input_field_names="text", output_field_names="sparse"
                            ),
            text_field="text",  # `text` is the input field name of BM25BuiltInFunction
            # `sparse` is the output field name of BM25BuiltInFunction, and `dense1` and `dense2` are the output field names of embedding1 and embedding2
            vector_field=["sparse"],
            connection_args={
                "uri": URI, "db_name": user_name
            },
            auto_id=False,
        )
# Out:
# ['default', 'sam', 'dheeraj']
# ['collect254', 'collect257', 'collect256', 'collect255', 'collect267']
# hi

# %%
doc = Document(metadata={'pages': '[15]', 'pk': '99454987799'}, page_content='hi samarjdksth, sammy')
doc.id = '1033902'

# %%
from vector_store_controller.milvus_db import MilvusDB_Sparse, MilvusDB_ANN, MilvusDB

# %%
m_sparse = MilvusDB_Sparse(user_name='sam', collection_name='collect254')
# Out:
# client created!

# %%
m_sparse.add_text_docs(texts=[doc])
# Out:
# [{'pages': '[15]', 'pk': '99987799'}] -->metadatas????

# %%
ret = m_sparse.client.as_retriever()

# %%
ret.invoke('sammy')
# Out:
# [Document(metadata={'pages': '[15]', 'pk': '999'}, page_content='hi samarth, sammy')]

# %%
m_ann = MilvusDB_ANN(user_name='sam', collection_name='collect255')

# %%
m_ann.add_text_docs([doc])
# Out:
# [{'pages': '[15]', 'pk': '99454987799'}] -->metadatas????

# %%
m_dense = MilvusDB(user_name = 'sam', collection_name='collect256')
m_dense.add_text_docs([doc])
# Out:
# collection inserted collect256
# [{'pages': '[15]', 'pk': '99454987799'}] -->metadatas????

# %%
m_dense.client.as_retriever().invoke('hi sammy')
# Out:
# [Document(metadata={'pages': '[15]', 'pk': '99454987799'}, page_content='hi samarjdksth, sammy'),
#  Document(metadata={'pages': '[]', 'pk': '0'}, page_content='init'),
#  Document(metadata={'pages': '[1]', 'pk': '245'}, page_content='Provided proper attribution is provided, Google hereby grants permission to\nreproduce the tables and figures in this paper solely for use in journalistic or\nscholarly works.\nAttention Is All You Need\nAshish Vaswani∗\nGoogle Brain\navaswani@google.com\nNoam Shazeer∗\nGoogle Brain\nnoam@google.com\nNiki Parmar∗\nGoogle Research\nnikip@google.com\nJakob Uszkoreit∗\nGoogle Research\nusz@google.com\nLlion Jones∗\nGoogle Research\nllion@google.com\nAidan N. Gomez∗†\nUniversity of Toronto\naidan@cs.toronto.edu\nŁukasz Kaiser∗\nGoogle Brain\nlukaszkaiser@google.com\nIllia Polosukhin∗‡\nillia.polosukhin@'),
# ...

# %%
from langchain_ollama import OllamaEmbeddings
embeddings = OllamaEmbeddings(model="mxbai-embed-large:latest", base_url='http://10.10.64.25:11434')
URI = "http://localhost:19530"

client = Milvus(
                collection_name = 'collect254',
                embedding_function = None,
                builtin_function=BM25BuiltInFunction(
                                    input_field_names="text", output_field_names="sparse"
                                ),
                text_field="text",  # `text` is the input field name of BM25BuiltInFunction
                # `sparse` is the output field name of BM25BuiltInFunction, and `dense1` and `dense2` are the output field names of embedding1 and embedding2
                vector_field=["sparse"],
                connection_args={
                    "uri": URI, "db_name": 'sam'
                },
                auto_id=False,
            )

# %%
client.add_documents([doc], ids = ['3244322'])
# Out:
# [{'pages': '[15]', 'pk': '99454987799'}] -->metadatas????
# ['99454987799']

# %%
r = client.as_retriever()

# %%
r.invoke('sammy')
# Out:
# [Document(metadata={'pages': '[15]', 'pk': '999899'}, page_content='hi samarth, sammy'),
#  Document(metadata={'pages': '[15]', 'pk': '999999'}, page_content='hi samarth, sammy'),
#  Document(metadata={'pages': '[15]', 'pk': '9999'}, page_content='hi samarth, sammy'),
#  Document(metadata={'pages': '[15]', 'pk': '999'}, page_content='hi samarth, sammy')]

# %%
from pymilvus import connections, Collection

# 1. Connect to Milvus
connections.connect(host="127.0.0.1", port=19530, db_name='sam')


# 2. Get the Collection object
collection_name = "collect254"  # Replace with your collection name
collection = Collection(collection_name)

# 3. Load the collection (if not already loaded)
collection.load()

# 4. Retrieve the number of entities
print(collection.num_entities)
# Out:
# 72

# %%
from uuid import uuid4

uuids = [str(uuid4()) for _ in range(len([doc]))]

client.add_documents(documents=[doc], ids = uuids)
# Out:
# [{'pages': '[15]', 'pk': '9999'}] -->metadatas????
# ['9999']

# %%
r = client.as_retriever(search_kwargs = {'k':10})

# %%
r.invoke('self samarth hi')
# Out:
# [Document(metadata={'pages': '[15]', 'pk': '999'}, page_content='hi samarth, saklasldfkammy'),
#  Document(metadata={'pages': '[1]', 'pk': '245'}, page_content='Provided proper attribution is provided, Google hereby grants permission to\nreproduce the tables and figures in this paper solely for use in journalistic or\nscholarly works.\nAttention Is All You Need\nAshish Vaswani∗\nGoogle Brain\navaswani@google.com\nNoam Shazeer∗\nGoogle Brain\nnoam@google.com\nNiki Parmar∗\nGoogle Research\nnikip@google.com\nJakob Uszkoreit∗\nGoogle Research\nusz@google.com\nLlion Jones∗\nGoogle Research\nllion@google.com\nAidan N. Gomez∗†\nUniversity of Toronto\naidan@cs.toronto.edu\nŁukasz Kaiser∗\nGoogle Brain\nlukaszkaiser@google.com\nIllia Polosukhin∗‡\nillia.polosukhin@'),
# ...

# %%
client.add_documents([doc])
# Out:
# [{'pages': '[15]', 'pk': '999'}] -->metadatas????
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 client.add_documents([doc])
#
# File c:\Users\samarth.srivastava\Desktop\new_check_proj\test_env2\lib\site-packages\langchain_milvus\vectorstores\milvus.py:1967, in Milvus.add_documents(self, documents, **kwargs)
#    1965 metadatas = [doc.metadata for doc in documents]
#    1966 print(metadatas, '-->metadatas????')
# -> 1967 return self.add_texts(texts, metadatas, **kwargs)
#
# File c:\Users\samarth.srivastava\Desktop\new_check_proj\test_env2\lib\site-packages\langchain_milvus\vectorstores\milvus.py:1089, in Milvus.add_texts(self, texts, metadatas, timeout, batch_size, ids, **kwargs)
#    1087 texts = list(texts)
#    1088 if not self.auto_id:
# -> 1089     assert isinstance(ids, list), (
# ...

# %%
embeddings = OllamaEmbeddings(model="mxbai-embed-large:latest", base_url='http://10.10.64.25:11434')
client = Milvus(
            embedding_function = embeddings,
            collection_name='collect257',
            connection_args={"uri": URI, 'db_name':'sam'},
        )

# %%
r = client.as_retriever()

# %%
r.invoke('self attention')
# Out:
# 21:34:49 httpx INFO   HTTP Request: POST http://10.10.64.25:11434/api/embed "HTTP/1.1 200 OK"
# [Document(metadata={'pages': '[15]', 'pk': '310'}, page_content='The\nLaw\nwill\nnever\nbe\nperfect\n,\nbut\nits\napplication\nshould\nbe\njust\n-\nthis\nis\nwhat\nwe\nare\nmissing\n,\nin\nmy\nopinion\n.\n<EOS>\n<pad>\nFigure 5: Many of the attention heads exhibit behaviour that seems related to the structure of the\nsentence. We give two such examples above, from two different heads from the encoder self-attention\nat layer 5 of 6. The heads clearly learned to perform different tasks.\n15\n'),
# ...

# %%
ret = client.as_retriever()

# %%
ret.invoke('self attention')[0]
# Out:
# Document(metadata={'pages': '[2]', 'pk': '252'}, page_content=' we counteract with Multi-Head Attention as\ndescribed in section 3.2.\nSelf-attention, sometimes called intra-attention is an attention mechanism relating different positions\nof a single sequence in order to compute a representation of the sequence. Self-attention has been\nused successfully in a variety of tasks including reading comprehension, abstractive summarization,\ntextual entailment and learning task-independent sentence representations [4, 27, 28, 22].\nEnd-to-end memory networks are based on a recurrent attention mechanism instead of sequence-\naligned recurrence and have been shown to perform well on simple-language question answering and\nlanguage modeling tasks [34].\nTo the best of our knowledge, however, the Transformer is the first transduction model relying\nentirely on self-attention to compute representations of its input and output without using sequence-\naligned RNNs or convolution. In the followi
# ...
